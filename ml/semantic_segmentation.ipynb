# %%
# https://colab.research.google.com/drive/18bJMQw-25zDD-oOQXG0UT1N0PL87u-Vl#scrollTo=UEPCt2YqAZW5
import torch
# import torchstat
# import oyaml
torch.cuda.is_available()
# Out:
# True

# %%
import hmmlearn

# %%
import sympy
